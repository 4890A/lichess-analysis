# %% [markdown]
# # An attempt to use the large datasets from lichess
# Download a dataset from https://database.lichess.org/ and place it in the same directory as this notebook.

# %%
import pandas as pd
import chess.pgn
import time
import chess.svg
from tqdm import tqdm

# name of dataset
pgn = open("lichess_db_standard_rated_2014-01.pgn")

# %%
# empty list to store data
blackelo = []
whiteelo = []
results = []
openings = []
ecos = []

# %%
for i in tqdm(range(100000)):
    game = chess.pgn.read_game(pgn)
    try:
        black = int(game.headers["BlackElo"])
        white = int(game.headers["WhiteElo"])
        opening = game.headers["Opening"]
        result = (game.headers["Result"])
        eco = (game.headers["ECO"])
        
        blackelo.append(black)
        whiteelo.append(white)
        openings.append(opening)
        results.append(result)
        ecos.append(eco)
    except:  
        continue
        

pgn.close()
# Out:
# 100%|██████████| 100000/100000 [06:30<00:00, 255.79it/s]

# %%
test = pd.DataFrame({"White Elo": whiteelo, "Black Elo": blackelo, "Result": results, 
                     "Opening": openings, "ECO": ecos})

# %%
test["Result"].unique()
# Out:
# array(['0-1', '1-0', '1/2-1/2'], dtype=object)

# %%
white_wins = []
translate = {'0-1': -1, '1-0':1, '1/2-1/2':0}
for i in results:
    white_wins.append(translate[i])

# %%
test["White Score"] = white_wins

# %%
opening_df = test.groupby(["Opening"])
opneing_results = pd.DataFrame(opening_df["White Score"].mean())
display(opneing_results)
opneing_results.sort_values("White Score", ascending=False)
# Out:
#                                                     White Score
# Opening
# ?                                                     -1.000000
# Alekhine Defense                                       0.212329
# Alekhine Defense #2                                    0.333333
# Alekhine Defense #3                                    0.142857
# Alekhine Defense: Balogh Variation                     0.272727
# Alekhine Defense: Brooklyn Variation                   0.437500
# Alekhine Defense: Exchange Variation                  -0.066667
# Alekhine Defense: Four Pawns Attack                    0.555556
# Alekhine Defense: Four Pawns Attack, 6...Nc6          -0.666667
# Alekhine Defense: Four Pawns Attack, Cambridge ...    -1.000000
# Alekhine Defense: Four Pawns Attack, Fianchetto...     0.333333
# Alekhine Defense: Four Pawns Attack, Main Line         0.555556
# Alekhine Defense: Four Pawns Attack, Trifunovic...     0.500000
# Alekhine Defense: Hunt Variation, Mikenas Gambit      -1.000000
# Alekhine Defense: John Tracy Gambit                    0.111111
# Alekhine Defense: Krejcik Variation                    0.166667
# Alekhine Defense: Krejcik Variation, Krejcik Ga...    -1.000000
# Alekhine Defense: Maroczy Variation                    0.050000
# Alekhine Defense: Modern Variation                     0.500000
# Alekhine Defense: Modern Variation, Alburt Vari...     0.333333
# Alekhine Defense: Modern Variation, Alekhine Ga...    -1.000000
# Alekhine Defense: Modern Variation, Larsen Vari...     0.333333
# Alekhine Defense: Modern Variation, Larsen-Haak...     0.272727
# Alekhine Defense: Modern Variation, Main Line         -0.111111
# Alekhine Defense: Modern Variation, Panov Varia...     0.000000
# Alekhine Defense: Modern Variation, Schmid Vari...     1.000000
# Alekhine Defense: Modern, Flohr Variation              1.000000
# Alekhine Defense: Mokele Mbembe                        0.634146
# Alekhine Defense: Mokele Mbembe, Vavra Defense         0.625000
# Alekhine Defense: Normal Variation                    -0.015625
# ...                                                         ...
# Zaire Defense                                          1.000000
# Zukertort Opening                                     -0.714286
# Zukertort Opening: Arctic Defense                      0.238095
# Zukertort Opening: Basman Defense                      0.500000
# Zukertort Opening: Black Mustang Defense              -0.087838
# Zukertort Opening: Double Fianchetto Attack           -1.000000
# Zukertort Opening: Dutch Variation                     0.130435
# Zukertort Opening: Gruenfeld Reversed                 -0.090909
# Zukertort Opening: Herrstrom Gambit                    0.333333
# Zukertort Opening: Kingside Fianchetto                -0.011628
# Zukertort Opening: Lisitsyn Gambit                     1.000000
# Zukertort Opening: Nimzo-Larsen Variation              0.300000
# Zukertort Opening: Old Indian Attack                   0.068493
# Zukertort Opening: Pirc Invitation                    -0.083871
# Zukertort Opening: Polish Defense                      0.600000
# Zukertort Opening: Queen's Gambit Invitation          -0.015152
# Zukertort Opening: Queenside Fianchetto Variation      0.285714
# Zukertort Opening: Quiet System                       -0.300000
# Zukertort Opening: Reversed Mexican Defense           -0.139535
# Zukertort Opening: Ross Gambit                         0.177778
# Zukertort Opening: Santasiere's Folly                  0.000000
# Zukertort Opening: Sicilian Invitation                -0.098361
# Zukertort Opening: Slav Invitation                     0.083333
# Zukertort Opening: Speelsmet Gambit                   -0.333333
# Zukertort Opening: St. George Defense                  0.333333
# Zukertort Opening: Tennison Gambit                    -0.063745
# Zukertort Opening: The Walrus                          0.000000
# Zukertort Opening: Vos Gambit                          0.214286
# Zukertort Opening: Wade Defense                       -0.138889
# Zukertort Opening: Ware Defense                        1.000000
#
# [1909 rows x 1 columns]
#                                                     White Score
# Opening
# Nimzo-Indian Defense: Normal Variation, Saemisc...          1.0
# King's Gambit, Falkbeer Countergambit, Hinrichs...          1.0
# King's Indian Defense: Orthodox Variation, Clas...          1.0
# King's Indian Defense: Orthodox Variation, Bayo...          1.0
# King's Indian Defense: Orthodox Variation, Aron...          1.0
# King's Indian Defense: Normal Variation, Standa...          1.0
# King's Indian Defense: Fianchetto Variation, Yu...          1.0
# King's Indian Defense: Fianchetto Variation, Pa...          1.0
# King's Indian Defense: Fianchetto Variation, Le...          1.0
# King's Indian Defense: Fianchetto Variation, Hu...          1.0
# King's Indian Defense: Averbakh Variation, Gell...          1.0
# King's Gambit: Panteldakis Countergambit, Greco...          1.0
# King's Gambit, Falkbeer Countergambit, Pickler ...          1.0
# King's Gambit Declined: Falkbeer, Rubinstein Va...          1.0
