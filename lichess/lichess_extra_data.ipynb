# %% [markdown]
# # An attempt to use the large datasets from lichess
# Download a dataset from https://database.lichess.org/ and place it in the same directory as this notebook.

# %%
import pandas as pd
import chess.pgn
import time
import chess.svg
from tqdm import tqdm

# name of dataset
# pgn = open("lichess_db_standard_rated_2014-01.pgn")

# %%
# empty list to store data
blackelo = []
whiteelo = []
results = []
openings = []
ecos = []

# %%
for i in tqdm(range(100000)):
    game = chess.pgn.read_game(pgn)
    try:
        black = int(game.headers["BlackElo"])
        white = int(game.headers["WhiteElo"])
        opening = game.headers["Opening"]
        result = (game.headers["Result"])
        eco = (game.headers["ECO"])
        
        blackelo.append(black)
        whiteelo.append(white)
        openings.append(opening)
        results.append(result)
        ecos.append(eco)
    except:  
        continue
        

pgn.close()
# Out:
# 100%|██████████| 100000/100000 [06:30<00:00, 255.79it/s]

# %%
test = pd.DataFrame({"White Elo": whiteelo, "Black Elo": blackelo, "Result": results, 
                     "Opening": openings, "ECO": ecos})

# %%
# convert results string to a single interger score
white_wins = []
translate = {'0-1': -1, '1-0':1, '1/2-1/2':0}
for i in results:
    white_wins.append(translate[i])
test["White Score"] = white_wins
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d58e378a7d4d> in <module>
#       1 white_wins = []
#       2 translate = {'0-1': -1, '1-0':1, '1/2-1/2':0}
# ----> 3 for i in results:
#       4     white_wins.append(translate[i])
#
# NameError: name 'results' is not defined

# %%
# load a prexisting csv
test = pd.read_csv("lichess_2015.csv")

# %%
# Group by openings, calculate average score. Filter by popular openings.

opening_df = test.groupby(["Opening"])
opening_results = pd.DataFrame(opening_df["White Score"].mean())
opening_count = opening_df["Result"].count()
opening_results["Count"] = opening_count
filtered_openings = opening_results.loc[opening_results["Count"] > 10000]
filtered_openings.sort_values("White Score", ascending=True)
# perhaps when checking for score, accumulate percentage win vs loss. in each column
# format strings by the colon
#filtered_openings.plot(kind="bar")
# Out:
#                                                White Score  Count
# Opening
# ?                                                -0.785188  18174
# Sicilian Defense                                 -0.122198  27259
# Sicilian Defense: Bowdler Attack                 -0.113436  22991
# Indian Game                                      -0.073106  16264
# Van't Kruijs Opening                             -0.063432  41998
# Caro-Kann Defense                                -0.060407  28159
# Sicilian Defense: Old Sicilian                   -0.048136  16495
# King's Pawn Game: Leonardis Variation            -0.046915  13386
# Old Benoni Defense                               -0.043720  13152
# Pirc Defense #4                                  -0.041187  13718
# Mieses Opening                                   -0.039022  14351
# Queen's Pawn Game                                -0.032192  15252
# French Defense: Knight Variation                 -0.025949  27092
# Scandinavian Defense                             -0.016361  22920
# Modern Defense                                   -0.007843  36085
# Sicilian Defense: McDonnell Attack               -0.007536  12473
# Hungarian Opening                                 0.025548  20941
# Queen's Pawn Game #2                              0.041607  20886
# Queen's Pawn Game: Chigorin Variation             0.045684  17402
# Philidor Defense #2                               0.047037  15371
# Bird Opening                                      0.051794  10117
# Queen's Gambit Declined                           0.059252  10160
# Owen Defense                                      0.076622  25815
# Queen's Pawn Game: Zukertort Variation            0.082795  15339
# Horwitz Defense                                   0.086209  31528
# English Defense #2                                0.100566  11485
# Bishop's Opening                                  0.113736  14859
# Queen's Pawn Game: Mason Attack                   0.117968  10647
# Philidor Defense #3                               0.167987  18805
# Scotch Game                                       0.175192  14858
# French Defense: Normal Variation                  0.180167  13654
# Scandinavian Defense: Mieses-Kotroc Variation     0.180807  32709
# Queen's Pawn                                      0.202299  22793
